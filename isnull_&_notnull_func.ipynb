# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.head(5)
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number  no values
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
df.isnull()
# Out:
#        Series_reference  Period  Data_value  Suppressed  STATUS  UNITS  \
# 0                 False   False       False        True   False  False
# 1                 False   False       False        True   False  False
# 2                 False   False       False        True   False  False
# 3                 False   False       False        True   False  False
# 4                 False   False       False        True   False  False
# ...                 ...     ...         ...         ...     ...    ...
# 20249             False   False        True       False   False  False
# 20250             False   False        True       False   False  False
# 20251             False   False        True       False   False  False
# 20252             False   False        True       False   False  False
# 20253             False   False        True       False   False  False
#
#        Magnitude  Subject  Group  Series_title_1  Series_title_2  \
# ...

# %% [markdown]
# # coloumn wise null value

# %%
df.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value           4459
# Suppressed          17379
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3          0
# Series_title_4      20254
# Series_title_5      20252
# dtype: int64

# %% [markdown]
# # total null values

# %%
df.isnull().sum().sum()
# Out:
# 62344

# %%
df.notnull().sum()
# Out:
# Series_reference    20254
# Period              20254
# Data_value          15795
# Suppressed           2875
# STATUS              20254
# UNITS               20254
# Magnitude           20254
# Subject             20254
# Group               20254
# Series_title_1      20254
# Series_title_2      20254
# Series_title_3      20254
# Series_title_4          0
# Series_title_5          2
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 221212

# %%
import numpy as np
s = pd.Series([1,2,3,np.nan,5,4,np.NAN])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# 5    4.0
# 6    NaN
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
s.isnull().sum()
