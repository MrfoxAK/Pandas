# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")
df
# Out:
#   12  Unnamed: 1  train no     ID Name   aa   we we.1
# 0  a         NaN       0.0  123.0  all    s  sds    s
# 1  b         NaN       1.0   45.0   ka  NaN  sds   sd
# 2  c         NaN       NaN   32.0   we   sd  sds  NaN
# 3  d         NaN       NaN    NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# # interpolate func is the func which is guess the nan value what should be filled in there

# %%
df.interpolate()
# Out:
#   12  Unnamed: 1  train no     ID Name   aa   we we.1
# 0  a         NaN       0.0  123.0  all    s  sds    s
# 1  b         NaN       1.0   45.0   ka  NaN  sds   sd
# 2  c         NaN       1.0   32.0   we   sd  sds  NaN
# 3  d         NaN       1.0   32.0  NaN  NaN  NaN  NaN

# %%
# did't guess str

# %%
# df.interpolate(method='time') # only works in date time

# %%
df.interpolate(method='index')
# Out:
#   12  Unnamed: 1  train no     ID Name   aa   we we.1
# 0  a         NaN       0.0  123.0  all    s  sds    s
# 1  b         NaN       1.0   45.0   ka  NaN  sds   sd
# 2  c         NaN       1.0   32.0   we   sd  sds  NaN
# 3  d         NaN       1.0   32.0  NaN  NaN  NaN  NaN

# %%
df.interpolate(method='nearest')
# Out:
#   12  Unnamed: 1  train no     ID Name   aa   we we.1
# 0  a         NaN       0.0  123.0  all    s  sds    s
# 1  b         NaN       1.0   45.0   ka  NaN  sds   sd
# 2  c         NaN       NaN   32.0   we   sd  sds  NaN
# 3  d         NaN       NaN    NaN  NaN  NaN  NaN  NaN

# %%
# lots of method 
# press shift + tab to see it
